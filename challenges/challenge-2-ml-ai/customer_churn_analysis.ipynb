# %% [markdown]
# # Customer Churn Prediction - ML Challenge
# ## GitHub Copilot Hackathon - Challenge 2
#
# Use GitHub Copilot to build a complete machine learning pipeline!
#
# **Goal**: Predict customer churn and provide actionable insights

# %% [markdown]
# ## 1. Setup and Imports
#
# 💡 **Copilot Tip**: Write a comment describing what libraries you need, let Copilot import them!

# %%
# Import necessary libraries for data analysis, visualization, and machine learning
# TODO: Let Copilot suggest the imports

# %% [markdown]
# ## 2. Load and Explore Data
#
# 💡 **Try this**: Comment what you want to do, then let Copilot generate the code

# %%
# Load the customer_churn.csv dataset and display basic information
# TODO: Use Copilot to generate data loading code

# %%
# Check for missing values and display the count for each column
# TODO: Let Copilot help

# %%
# Display statistical summary of the dataset
# TODO: Ask Copilot for descriptive statistics

# %% [markdown]
# ## 3. Data Visualization
#
# 💡 **Copilot Pro Tip**: Ask for specific visualizations in comments

# %%
# Create a visualization showing the distribution of churn (target variable)
# TODO: Use Copilot to create a count plot

# %%
# Create a correlation heatmap for numerical features
# TODO: Let Copilot generate the heatmap code

# %%
# Visualize churn rate by contract type using a bar plot
# TODO: Ask Copilot for grouped analysis

# %% [markdown]
# ## 4. Feature Engineering
#
# 💡 **Use Copilot Chat**: Ask "What features should I create for churn prediction?"

# %%
# Create new features: tenure_group, avg_monthly_charges, service_count
# TODO: Let Copilot help with feature engineering

# %%
# Encode categorical variables using appropriate encoding methods
# TODO: Use Copilot for one-hot encoding and label encoding

# %% [markdown]
# ## 5. Model Development
#
# 💡 **Copilot Workflow**: Comment -> Generate -> Review -> Refine

# %%
# Split data into training and testing sets (80/20 split, stratified by churn)
# TODO: Ask Copilot to create train/test split

# %%
# Train multiple models: Logistic Regression, Random Forest, Gradient Boosting
# Compare their performance using accuracy, precision, recall, and F1-score
# TODO: Use Copilot to generate model training and comparison code

# %% [markdown]
# ## 6. Model Evaluation
#
# 💡 **Use `/explain`**: Highlight model code and ask Copilot to explain the algorithm

# %%
# Evaluate the best model on test set
# Display confusion matrix, classification report, and ROC curve
# TODO: Let Copilot create comprehensive evaluation

# %%
# Extract and visualize feature importance from the best model
# TODO: Use Copilot to show top 10 important features

# %% [markdown]
# ## 7. Insights and Recommendations
#
# 💡 **Ask Copilot**: "What insights can we derive from this model?"

# %%
# Analyze the results and generate business insights
# Create a summary of key findings
# TODO: Use Copilot to help document insights

# %% [markdown]
# ## 🎓 Reflection
#
# Answer these questions about your Copilot experience:
#
# 1. Which Copilot suggestions were most helpful?
# 2. Did you use `/explain`, `/fix`, or `/test`? How did they help?
# 3. What percentage of code was generated vs. written manually?
# 4. What would you do differently next time?
