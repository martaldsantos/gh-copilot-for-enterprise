# %% [markdown]
# # Customer Churn Prediction
#
# Predict customer churn using a complete ML pipeline.
#
# The dataset is intentionally messy -- it contains missing values, inconsistent formatting,
# duplicate rows, mixed data types, and other quality issues. Your first task is to discover
# and document every problem before building models.
#
# ## Challenge Stages
#
# 1. **Data Discovery and Cleaning** -- Find all data quality issues, clean them, write a quality report
# 2. **Exploratory Analysis and Feature Engineering** -- Visualizations with interpretation, hypothesis testing, feature selection
# 3. **Model Development and Rigorous Evaluation** -- Multiple models with pipelines, cross-validation, cost-sensitive scoring
# 4. **Class Imbalance and Interpretability** -- Imbalance techniques comparison, SHAP analysis, business recommendations
# 5. **Deployment Pipeline and Monitoring** -- Model serialization, prediction API, drift detection, model card

# %% [markdown]
# ## Stage 1: Data Discovery and Cleaning
#
# ### Setup and Imports

# %%
# Import libraries for data analysis, visualization, and machine learning

# %% [markdown]
# ### Data Loading and Inspection
#
# Load the dataset and inspect its structure. The dataset has 7+ distinct data quality
# problems -- find them all before proceeding.

# %%
# Load dataset and display basic information

# %%
# Inspect data quality: types, nulls, duplicates, inconsistencies

# %%
# Clean all discovered issues and write a Data Quality Report below
# For each issue: describe what you found, its impact, and why you chose this fix

# %% [markdown]
# ## Stage 2: Exploratory Analysis and Feature Engineering
#
# ### Visualizations
#
# Create at least 8 visualizations. Each must include a written interpretation
# explaining what the plot reveals about churn behavior.

# %%
# Visualizations with written interpretations

# %%
# Statistical hypothesis testing: test at least 2 hypotheses with p-values

# %%
# Feature engineering: create at least 5 new features with business rationale

# %% [markdown]
# ### Feature Selection
#
# Compare at least 2 feature selection methods (e.g., correlation, mutual information,
# recursive feature elimination). Justify your final feature set.

# %%
# Feature selection comparison

# %%
# Encode categorical variables and scale numerical features

# %% [markdown]
# ## Stage 3: Model Development and Rigorous Evaluation
#
# Train at least 4 models using sklearn Pipeline objects. Use stratified k-fold
# cross-validation and hyperparameter tuning. Define a custom cost-sensitive scorer
# where false negatives cost 5x more than false positives.

# %%
# Train/test split, model training with pipelines, cross-validation

# %%
# Hyperparameter tuning with custom cost-sensitive scorer

# %% [markdown]
# ### Model Evaluation
#
# Evaluate models with confusion matrix, classification report, ROC curve, and
# feature importance. Report cross-validation scores with standard deviation.

# %%
# Model evaluation: confusion matrix, classification report, ROC curve

# %%
# Feature importance visualization

# %% [markdown]
# ## Stage 4: Class Imbalance and Interpretability
#
# Implement and compare at least 3 imbalance techniques. For each, report all
# metrics and explain which metric matters most for the business case.
#
# Generate SHAP analysis: summary plot, dependence plots for top 3 features,
# force plots for 3 individual predictions. Write a Model Explainability Report
# with specific, actionable business recommendations.

# %%
# Class imbalance comparison: SMOTE, class weights, random undersampling

# %% [markdown]
# ### SHAP Analysis and Model Explainability Report

# %%
# SHAP analysis: summary plot, dependence plots, force plots

# %% [markdown]
# ## Stage 5: Deployment Pipeline and Monitoring
#
# Serialize the best model with its full preprocessing pipeline. Create a prediction
# API endpoint in `serve_model.py`. Implement data drift detection. Write a Model Card
# using the template in `model_card_template.md`.

# %%
# Model serialization and prediction function

# %% [markdown]
# ### Data Drift Detection and Monitoring
#
# Simulate 100 new customers and show how predictions and confidence change as
# feature distributions drift from training data. Use KS-test or PSI to detect drift.
